# %% [markdown]
# # Tokenizers

# %% [markdown]
# ## Word-based

# %%
tokenized_text = "Jim Henson was a puppeteer".split()
print(tokenized_text)
# Out:
# ['Jim', 'Henson', 'was', 'a', 'puppeteer']

# %% [markdown]
# ## Character-based

# %%
tokenized_text = list("Jim Henson was a puppeteer".replace(' ', ''))
print(tokenized_text)
# Out:
# ['J', 'i', 'm', 'H', 'e', 'n', 's', 'o', 'n', 'w', 'a', 's', 'a', 'p', 'u', 'p', 'p', 'e', 't', 'e', 'e', 'r']

# %% [markdown]
# ## Subword tokenization
# Subword tokenization algorithms rely on the principle that frequently used words should not be split into smaller subwords, but rare words should be decomposed into meaningful subwords.

# %% [markdown]
# ## Loading and saving

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained("bert-base-cased")

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

# %%
tokenizer("Using a Transformer network is simple")
# Out:
# {'input_ids': [101, 7993, 170, 13809, 23763, 2443, 1110, 3014, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1, 1]}

# %%
tokenizer.save_pretrained(r"C:\Users\Angel Hesse\Desktop\AI-LLM-DEVELOPMENT-ROADMAP\06 - LLM Course (Hugging Face)\Testing_Things_on_Notebooks\\models\\testing_model")
# Out:
# ('C:\\Users\\Angel Hesse\\Desktop\\AI-LLM-DEVELOPMENT-ROADMAP\\06 - LLM Course (Hugging Face)\\Testing_Things_on_Notebooks\\\\models\\\\testing_model\\tokenizer_config.json',
#  'C:\\Users\\Angel Hesse\\Desktop\\AI-LLM-DEVELOPMENT-ROADMAP\\06 - LLM Course (Hugging Face)\\Testing_Things_on_Notebooks\\\\models\\\\testing_model\\special_tokens_map.json',
#  'C:\\Users\\Angel Hesse\\Desktop\\AI-LLM-DEVELOPMENT-ROADMAP\\06 - LLM Course (Hugging Face)\\Testing_Things_on_Notebooks\\\\models\\\\testing_model\\vocab.txt',
#  'C:\\Users\\Angel Hesse\\Desktop\\AI-LLM-DEVELOPMENT-ROADMAP\\06 - LLM Course (Hugging Face)\\Testing_Things_on_Notebooks\\\\models\\\\testing_model\\added_tokens.json',
#  'C:\\Users\\Angel Hesse\\Desktop\\AI-LLM-DEVELOPMENT-ROADMAP\\06 - LLM Course (Hugging Face)\\Testing_Things_on_Notebooks\\\\models\\\\testing_model\\tokenizer.json')

# %% [markdown]
# ## Encoding

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

sequence = "Using a Transformer network is simple"
tokens = tokenizer.tokenize(sequence)

print(tokens)
# Out:
# ['Using', 'a', 'Trans', '##former', 'network', 'is', 'simple']

# %% [markdown]
# ## From tokens to input IDs

# %%
ids = tokenizer.convert_tokens_to_ids(tokens)

print(ids)
# Out:
# [7993, 170, 13809, 23763, 2443, 1110, 3014]

# %% [markdown]
# ## Decoding

# %%
decoded_string = tokenizer.decode([7993, 170, 11303, 1200, 2443, 1110, 3014])
print(decoded_string)
# Out:
# Using a transformer network is simple
